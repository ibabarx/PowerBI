# %% [markdown]
# ### **Import necessary Libraries**

# %%
import pandas as pd
from sklearn.impute import KNNImputer

# %% [markdown]
# ### **Import Data**

# %%
original = pd.read_csv('/content/sample_data/country_based_data.csv')

# %% [markdown]
# ### **Observe the Data**

# %%
original.shape
# Out:
# (12622, 51)

# %%
original.isnull().sum()

# %% [markdown]
# A lot of Null values found in all the columns

# %% [markdown]
# ### **Make a Copy of the original Data**

# %%
data_copy = original.copy()

# %%
data_copy.drop('Unnamed: 0',axis='columns',inplace=True)

# %% [markdown]
# ### **Check the Datatypes of columns**

# %%
data_copy.dtypes

# %% [markdown]
# ### **Check number of instances of each country**

# %%
for country_name in list(set(data_copy['country'])):
    a = data_copy[data_copy['country'] == country_name].shape
    print(a)

# %% [markdown]
# Turkey and Czech Republic have incomplete data (Later we find out that all columns are empty, therefore we delete the data of these countries)

# %% [markdown]
# ### **Replace columns that are completely Null with 0 for each country seperately**

# %%
data_copy = data_copy[~data_copy['country'].isin(['Turkey','Czech Republic'])]

for country_name in set(data_copy['country']):
    data_concerned = data_copy[data_copy['country'] == country_name]
    all_null = data_concerned.columns[data_concerned.isnull().sum() == 63]
    data_copy.loc[data_copy['country'] == country_name, all_null] = data_copy.loc[data_copy['country'] == country_name, all_null].fillna(0)

# %% [markdown]
# We fill 0 for columns that are completely 0 for every country to prevent any issue during KNN Imputer, knn Imputing is done seperately for each country  to prevent imputer taking data of seperate countries into consideration.

# %%
data_copy
# Out:
#            country        date  agricultural_land%  forest_land%  land_area  \
# 0      Afghanistan  1960-01-01                 NaN           NaN        NaN
# 1      Afghanistan  1961-01-01           57.801696           NaN   652230.0
# 2      Afghanistan  1962-01-01           57.893688           NaN   652230.0
# 3      Afghanistan  1963-01-01           57.970348           NaN   652230.0
# 4      Afghanistan  1964-01-01           58.066940           NaN   652230.0
# ...            ...         ...                 ...           ...        ...
# 12617     Zimbabwe  2018-01-01           41.876696     45.332093   386850.0
# 12618     Zimbabwe  2019-01-01           41.876696     45.213002   386850.0
# 12619     Zimbabwe  2020-01-01           41.876696     45.093912   386850.0
# 12620     Zimbabwe  2021-01-01                 NaN           NaN        NaN
# 12621     Zimbabwe  2022-01-01                 NaN           NaN        NaN
#
#        avg_precipitation  trade_in_services%  control_of_corruption_estimate  \
# 0                    NaN                 NaN                             NaN
# 1                  327.0                 NaN                             NaN
# 2                  327.0                 NaN                             NaN
# 3                  327.0                 NaN                             NaN
# 4                  327.0                 NaN                             NaN
# ...                  ...                 ...                             ...
# 12617              657.0            4.469742                       -1.227581
# 12618              657.0            6.927164                       -1.273280
# 12619              657.0            5.118949                       -1.289440
# 12620                NaN                 NaN                       -1.257897
# 12621                NaN                 NaN                             NaN
#
#        control_of_corruption_std  access_to_electricity%  ...  \
# 0                            NaN                     NaN  ...
# 1                            NaN                     NaN  ...
# 2                            NaN                     NaN  ...
# 3                            NaN                     NaN  ...
# 4                            NaN                     NaN  ...
# ...                          ...                     ...  ...
# 12617                   0.125622               45.400288  ...
# 12618                   0.135450               46.682095  ...
# 12619                   0.142061               52.747667  ...
# 12620                   0.154067               48.979927  ...
# 12621                        NaN                     NaN  ...
#
#        multidimensional_poverty_headcount_ratio%  gini_index  birth_rate  \
# 0                                            NaN         0.0      50.340
# 1                                            NaN         0.0      50.443
# 2                                            NaN         0.0      50.570
# 3                                            NaN         0.0      50.703
# 4                                            NaN         0.0      50.831
# ...                                          ...         ...         ...
# 12617                                        0.0         NaN      32.074
# 12618                                        0.0        50.3      31.518
# 12619                                        0.0         NaN      31.009
# 12620                                        0.0         NaN      30.537
# 12621                                        0.0         NaN         NaN
#
#        death_rate  life_expectancy_at_birth  population  rural_population  \
# 0          31.921                    32.535   8622466.0         7898093.0
# 1          31.349                    33.068   8790140.0         8026804.0
# 2          30.845                    33.547   8969047.0         8163985.0
# 3          30.359                    34.016   9157465.0         8308019.0
# 4          29.867                    34.494   9355514.0         8458694.0
# ...           ...                       ...         ...               ...
# 12617       7.972                    61.414  15052184.0        10204026.0
# 12618       8.043                    61.292  15354608.0        10408889.0
# 12619       8.132                    61.124  15669666.0        10617452.0
# 12620       9.057                    59.253  15993524.0        10827136.0
# 12621         NaN                       NaN  16320537.0        11033499.0
#
#        voice_and_accountability_estimate  voice_and_accountability_std  \
# 0                                    NaN                           NaN
# 1                                    NaN                           NaN
# 2                                    NaN                           NaN
# 3                                    NaN                           NaN
# 4                                    NaN                           NaN
# ...                                  ...                           ...
# 12617                          -1.140975                      0.123371
# 12618                          -1.164705                      0.118156
# 12619                          -1.113716                      0.120647
# 12620                          -1.136934                      0.121119
# 12621                                NaN                           NaN
#
#        intentional_homicides
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 12617               4.876369
# 12618               5.145035
# 12619               4.977770
# 12620               6.139985
# 12621                    NaN
#
# [12600 rows x 50 columns]

# %%
data_copy.isnull().sum()

# %% [markdown]
# ### **Imputing using KNN Imputer for Missing Values**

# %%
imputing_columns = data_copy.drop(['country', 'date'], axis='columns').columns

data_cleaned = pd.DataFrame(columns=list(imputing_columns) + ['Country', 'year'])  # Corrected column assignment

for country_name in set(data_copy['country']):
    data_imputed = KNNImputer(n_neighbors=3).fit_transform(data_copy[data_copy['country'] == country_name][imputing_columns])
    imputed_df = pd.DataFrame(data_imputed, columns=imputing_columns)
    imputed_df['Country'] = country_name
    imputed_df['year'] = pd.to_datetime(data_copy.loc[data_copy['country'] == country_name, 'date']).dt.year.values
    data_cleaned = pd.concat([data_cleaned,imputed_df], ignore_index=True)

# %%
data_cleaned
# Out:
#        agricultural_land%  forest_land%  land_area  avg_precipitation  \
# 0                2.928752      3.540453    71020.0               78.0
# 1                2.928752      3.540453    71020.0               78.0
# 2                2.928752      3.540453    71020.0               78.0
# 3                2.928752      3.540453    71020.0               78.0
# 4                2.928752      3.540453    71020.0               78.0
# ...                   ...           ...        ...                ...
# 12595           20.625754     43.266442   472710.0             1604.0
# 12596           20.625754     43.147977   472710.0             1604.0
# 12597           20.625754     43.029511   472710.0             1604.0
# 12598           20.625754     43.147977   472710.0             1604.0
# 12599           20.625754     43.147977   472710.0             1604.0
#
#        trade_in_services%  control_of_corruption_estimate  \
# 0                0.000000                        0.043600
# 1                0.000000                        0.043600
# 2                0.000000                        0.043600
# 3                0.000000                        0.043600
# 4                0.000000                        0.043600
# ...                   ...                             ...
# 12595           12.062652                       -1.144107
# 12596           12.674736                       -1.194021
# 12597            9.383638                       -1.114791
# 12598            8.691039                       -1.092714
# 12599           10.045776                       -1.117204
#
#        control_of_corruption_std  access_to_electricity%  \
# 0                       0.285655              100.000000
# 1                       0.285655              100.000000
# 2                       0.285655              100.000000
# 3                       0.285655              100.000000
# 4                       0.285655              100.000000
# ...                          ...                     ...
# 12595                   0.125622               62.200000
# 12596                   0.132429               63.176895
# 12597                   0.135698               64.311874
# 12598                   0.146758               65.446709
# 12599                   0.136026               63.986194
#
#        renewvable_energy_consumption%  electric_power_consumption  ...  \
# 0                            0.063333                 1058.971352  ...
# 1                            0.063333                 1058.971352  ...
# 2                            0.063333                 1058.971352  ...
# 3                            0.063333                 1058.971352  ...
# 4                            0.063333                 1058.971352  ...
# ...                               ...                         ...  ...
# 12595                       78.570000                  266.456697  ...
# 12596                       78.790000                  266.456697  ...
# 12597                       78.940000                  266.456697  ...
# 12598                       78.766667                  266.456697  ...
# 12599                       78.766667                  263.350447  ...
#
#        birth_rate  death_rate  life_expectancy_at_birth  population  \
# 0       41.814000      15.546                    48.811    133426.0
# 1       41.392000      14.963                    49.695    140984.0
# 2       41.062000      14.290                    50.686    148877.0
# 3       40.601000      13.610                    51.584    157006.0
# 4       40.003000      12.667                    52.848    165305.0
# ...           ...         ...                       ...         ...
# 12595   36.716000       8.379                    61.180  25076747.0
# 12596   36.147000       8.160                    61.584  25782341.0
# 12597   35.507000       8.419                    60.833  26491087.0
# 12598   34.938000       8.582                    60.333  27198628.0
# 12599   35.720333       8.460                    60.782  27914536.0
#
#        rural_population  voice_and_accountability_estimate  \
# 0               35358.0                          -0.481803
# 1               36116.0                          -0.481803
# 2               36850.0                          -0.481803
# 3               37535.0                          -0.481803
# 4               38154.0                          -0.481803
# ...                 ...                                ...
# 12595        10939982.0                          -1.133223
# 12596        11094657.0                          -1.209367
# 12597        11242817.0                          -1.205425
# 12598        11383170.0                          -1.160156
# 12599        11519492.0                          -1.166268
#
#        voice_and_accountability_std  intentional_homicides  \
# 0                          0.228029               0.726992
# 1                          0.228029               0.726992
# 2                          0.228029               0.726992
# 3                          0.228029               0.726992
# 4                          0.228029               0.726992
# ...                             ...                    ...
# 12595                      0.123371               3.990775
# 12596                      0.117767               3.990775
# 12597                      0.120301               4.537375
# 12598                      0.120698               3.990775
# 12599                      0.121457               3.990775
#
#                     Country  year
# 0      United Arab Emirates  1960
# 1      United Arab Emirates  1961
# 2      United Arab Emirates  1962
# 3      United Arab Emirates  1963
# 4      United Arab Emirates  1964
# ...                     ...   ...
# 12595              Cameroon  2018
# 12596              Cameroon  2019
# 12597              Cameroon  2020
# 12598              Cameroon  2021
# 12599              Cameroon  2022
#
# [12600 rows x 50 columns]

# %%
data_cleaned.isnull().sum()
# Out:
# agricultural_land%                           0
# forest_land%                                 0
# land_area                                    0
# avg_precipitation                            0
# trade_in_services%                           0
# control_of_corruption_estimate               0
# control_of_corruption_std                    0
# access_to_electricity%                       0
# renewvable_energy_consumption%               0
# electric_power_consumption                   0
# CO2_emisions                                 0
# other_greenhouse_emisions                    0
# population_density                           0
# inflation_annual%                            0
# real_interest_rate                           0
# risk_premium_on_lending                      0
# research_and_development_expenditure%        0
# central_goverment_debt%                      0
# tax_revenue%                                 0
# expense%                                     0
# goverment_effectiveness_estimate             0
# goverment_effectiveness_std                  0
# human_capital_index                          0
# doing_business                               0
# time_to_get_operation_license                0
# statistical_performance_indicators           0
# individuals_using_internet%                  0
# logistic_performance_index                   0
# military_expenditure%                        0
# GDP_current_US                               0
# political_stability_estimate                 0
# political_stability_std                      0
# rule_of_law_estimate                         0
# rule_of_law_std                              0
# regulatory_quality_estimate                  0
# regulatory_quality_std                       0
# government_expenditure_on_education%         0
# government_health_expenditure%               0
# multidimensional_poverty_headcount_ratio%    0
# gini_index                                   0
# birth_rate                                   0
# death_rate                                   0
# life_expectancy_at_birth                     0
# population                                   0
# rural_population                             0
# voice_and_accountability_estimate            0
# voice_and_accountability_std                 0
# intentional_homicides                        0
# Country                                      0
# year                                         0
# dtype: int64

# %% [markdown]
# ### **Exporting the Cleaned Data**

# %%
data_cleaned.to_csv('country_data_cleaned.csv')
