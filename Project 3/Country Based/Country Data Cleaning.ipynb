# %% [markdown]
# ### **Import necessary Libraries**

# %%
import pandas as pd
from sklearn.impute import KNNImputer

# %% [markdown]
# ### **Import Data**

# %%
original = pd.read_csv('/content/sample_data/country_based_data.csv')

# %% [markdown]
# ### **Observe the Data**

# %%
original.shape
# Out:
# (12622, 51)

# %%
original.isnull().sum()
# Out:
# Unnamed: 0                                       0
# country                                          0
# date                                             0
# agricultural_land%                             864
# forest_land%                                  6577
# land_area                                      804
# avg_precipitation                             2536
# trade_in_services%                            5695
# control_of_corruption_estimate                8186
# control_of_corruption_std                     8186
# access_to_electricity%                        7032
# renewvable_energy_consumption%                6511
# electric_power_consumption                    6851
# CO2_emisions                                  6702
# other_greenhouse_emisions                     6702
# population_density                             833
# inflation_annual%                             4189
# real_interest_rate                            8295
# risk_premium_on_lending                      10286
# research_and_development_expenditure%        10541
# central_goverment_debt%                      10782
# tax_revenue%                                  8389
# expense%                                      8580
# goverment_effectiveness_estimate              8210
# goverment_effectiveness_std                   8210
# human_capital_index                          12029
# doing_business                               12434
# time_to_get_operation_license                12307
# statistical_performance_indicators           11933
# individuals_using_internet%                   6428
# logistic_performance_index                   11558
# military_expenditure%                         5215
# GDP_current_US                                2485
# political_stability_estimate                  8135
# political_stability_std                       8135
# rule_of_law_estimate                          8096
# rule_of_law_std                               8096
# regulatory_quality_estimate                   8208
# regulatory_quality_std                        8208
# government_expenditure_on_education%          7947
# government_health_expenditure%                8692
# multidimensional_poverty_headcount_ratio%    12128
# gini_index                                   10686
# birth_rate                                     441
# death_rate                                     463
# life_expectancy_at_birth                       572
# population                                      52
# rural_population                               115
# voice_and_accountability_estimate             8082
# voice_and_accountability_std                  8082
# intentional_homicides                         8891
# dtype: int64

# %% [markdown]
# A lot of Null values found in all the columns

# %% [markdown]
# ### **Make a Copy of the original Data**

# %%
data_copy = original.copy()

# %%
data_copy.drop('Unnamed: 0',axis='columns',inplace=True)

# %% [markdown]
# ### **Check the Datatypes of columns**

# %%
data_copy.dtypes
# Out:
# country                                       object
# date                                          object
# agricultural_land%                           float64
# forest_land%                                 float64
# land_area                                    float64
# avg_precipitation                            float64
# trade_in_services%                           float64
# control_of_corruption_estimate               float64
# control_of_corruption_std                    float64
# access_to_electricity%                       float64
# renewvable_energy_consumption%               float64
# electric_power_consumption                   float64
# CO2_emisions                                 float64
# other_greenhouse_emisions                    float64
# population_density                           float64
# inflation_annual%                            float64
# real_interest_rate                           float64
# risk_premium_on_lending                      float64
# research_and_development_expenditure%        float64
# central_goverment_debt%                      float64
# tax_revenue%                                 float64
# expense%                                     float64
# goverment_effectiveness_estimate             float64
# goverment_effectiveness_std                  float64
# human_capital_index                          float64
# doing_business                               float64
# time_to_get_operation_license                float64
# statistical_performance_indicators           float64
# individuals_using_internet%                  float64
# logistic_performance_index                   float64
# military_expenditure%                        float64
# GDP_current_US                               float64
# political_stability_estimate                 float64
# political_stability_std                      float64
# rule_of_law_estimate                         float64
# rule_of_law_std                              float64
# regulatory_quality_estimate                  float64
# regulatory_quality_std                       float64
# government_expenditure_on_education%         float64
# government_health_expenditure%               float64
# multidimensional_poverty_headcount_ratio%    float64
# gini_index                                   float64
# birth_rate                                   float64
# death_rate                                   float64
# life_expectancy_at_birth                     float64
# population                                   float64
# rural_population                             float64
# voice_and_accountability_estimate            float64
# voice_and_accountability_std                 float64
# intentional_homicides                        float64
# dtype: object

# %% [markdown]
# ### **Check number of instances of each country**

# %%
for country_name in list(set(data_copy['country'])):
    a = data_copy[data_copy['country'] == country_name].shape
    print(a)
# Out:
# (63, 50)
# (11, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (11, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)
# (63, 50)

# %% [markdown]
# Turkey and Czech Republic have incomplete data (Later we find out that all columns are empty, therefore we delete the data of these countries)

# %% [markdown]
# ### **Replace columns that are completely Null with 0 for each country seperately**

# %%
data_copy = data_copy[~data_copy['country'].isin(['Turkey','Czech Republic'])]

for country_name in set(data_copy['country']):
    data_concerned = data_copy[data_copy['country'] == country_name]
    all_null = data_concerned.columns[data_concerned.isnull().sum() == 63]
    data_copy.loc[data_copy['country'] == country_name, all_null] = data_copy.loc[data_copy['country'] == country_name, all_null].fillna(0)

# %% [markdown]
# We fill 0 for columns that are completely 0 for every country to prevent any issue during KNN Imputer, knn Imputing is done seperately for each country  to prevent imputer taking data of seperate countries into consideration.

# %%
data_copy
# Out:
#            country        date  agricultural_land%  forest_land%  land_area  \
# 0      Afghanistan  1960-01-01                 NaN           NaN        NaN
# 1      Afghanistan  1961-01-01           57.801696           NaN   652230.0
# 2      Afghanistan  1962-01-01           57.893688           NaN   652230.0
# 3      Afghanistan  1963-01-01           57.970348           NaN   652230.0
# 4      Afghanistan  1964-01-01           58.066940           NaN   652230.0
# ...            ...         ...                 ...           ...        ...
# 12617     Zimbabwe  2018-01-01           41.876696     45.332093   386850.0
# 12618     Zimbabwe  2019-01-01           41.876696     45.213002   386850.0
# 12619     Zimbabwe  2020-01-01           41.876696     45.093912   386850.0
# 12620     Zimbabwe  2021-01-01                 NaN           NaN        NaN
# 12621     Zimbabwe  2022-01-01                 NaN           NaN        NaN
#
#        avg_precipitation  trade_in_services%  control_of_corruption_estimate  \
# 0                    NaN                 NaN                             NaN
# 1                  327.0                 NaN                             NaN
# 2                  327.0                 NaN                             NaN
# 3                  327.0                 NaN                             NaN
# 4                  327.0                 NaN                             NaN
# ...                  ...                 ...                             ...
# 12617              657.0            4.469742                       -1.227581
# 12618              657.0            6.927164                       -1.273280
# 12619              657.0            5.118949                       -1.289440
# 12620                NaN                 NaN                       -1.257897
# 12621                NaN                 NaN                             NaN
#
#        control_of_corruption_std  access_to_electricity%  ...  \
# 0                            NaN                     NaN  ...
# 1                            NaN                     NaN  ...
# 2                            NaN                     NaN  ...
# 3                            NaN                     NaN  ...
# 4                            NaN                     NaN  ...
# ...                          ...                     ...  ...
# 12617                   0.125622               45.400288  ...
# 12618                   0.135450               46.682095  ...
# 12619                   0.142061               52.747667  ...
# 12620                   0.154067               48.979927  ...
# 12621                        NaN                     NaN  ...
#
#        multidimensional_poverty_headcount_ratio%  gini_index  birth_rate  \
# 0                                            NaN         0.0      50.340
# 1                                            NaN         0.0      50.443
# 2                                            NaN         0.0      50.570
# 3                                            NaN         0.0      50.703
# 4                                            NaN         0.0      50.831
# ...                                          ...         ...         ...
# 12617                                        0.0         NaN      32.074
# 12618                                        0.0        50.3      31.518
# 12619                                        0.0         NaN      31.009
# 12620                                        0.0         NaN      30.537
# 12621                                        0.0         NaN         NaN
#
#        death_rate  life_expectancy_at_birth  population  rural_population  \
# 0          31.921                    32.535   8622466.0         7898093.0
# 1          31.349                    33.068   8790140.0         8026804.0
# 2          30.845                    33.547   8969047.0         8163985.0
# 3          30.359                    34.016   9157465.0         8308019.0
# 4          29.867                    34.494   9355514.0         8458694.0
# ...           ...                       ...         ...               ...
# 12617       7.972                    61.414  15052184.0        10204026.0
# 12618       8.043                    61.292  15354608.0        10408889.0
# 12619       8.132                    61.124  15669666.0        10617452.0
# 12620       9.057                    59.253  15993524.0        10827136.0
# 12621         NaN                       NaN  16320537.0        11033499.0
#
#        voice_and_accountability_estimate  voice_and_accountability_std  \
# 0                                    NaN                           NaN
# 1                                    NaN                           NaN
# 2                                    NaN                           NaN
# 3                                    NaN                           NaN
# 4                                    NaN                           NaN
# ...                                  ...                           ...
# 12617                          -1.140975                      0.123371
# 12618                          -1.164705                      0.118156
# 12619                          -1.113716                      0.120647
# 12620                          -1.136934                      0.121119
# 12621                                NaN                           NaN
#
#        intentional_homicides
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 12617               4.876369
# 12618               5.145035
# 12619               4.977770
# 12620               6.139985
# 12621                    NaN
#
# [12600 rows x 50 columns]

# %%
data_copy.isnull().sum()
# Out:
# country                                          0
# date                                             0
# agricultural_land%                             716
# forest_land%                                  6492
# land_area                                      719
# avg_precipitation                             1380
# trade_in_services%                            5043
# control_of_corruption_estimate                7975
# control_of_corruption_std                     7975
# access_to_electricity%                        7010
# renewvable_energy_consumption%                6300
# electric_power_consumption                    2986
# CO2_emisions                                  6113
# other_greenhouse_emisions                     6113
# population_density                             748
# inflation_annual%                             3285
# real_interest_rate                            4871
# risk_premium_on_lending                       3082
# research_and_development_expenditure%         6991
# central_goverment_debt%                       5720
# tax_revenue%                                  5784
# expense%                                      5786
# goverment_effectiveness_estimate              7999
# goverment_effectiveness_std                   7999
# human_capital_index                          10125
# doing_business                               11656
# time_to_get_operation_license                 9261
# statistical_performance_indicators           10273
# individuals_using_internet%                   6406
# logistic_performance_index                    9520
# military_expenditure%                         2925
# GDP_current_US                                2400
# political_stability_estimate                  8050
# political_stability_std                       8050
# rule_of_law_estimate                          8011
# rule_of_law_std                               8011
# regulatory_quality_estimate                   7997
# regulatory_quality_std                        7997
# government_expenditure_on_education%          7547
# government_health_expenditure%                8040
# multidimensional_poverty_headcount_ratio%     3727
# gini_index                                    8585
# birth_rate                                     419
# death_rate                                     441
# life_expectancy_at_birth                       361
# population                                      30
# rural_population                                30
# voice_and_accountability_estimate             7997
# voice_and_accountability_std                  7997
# intentional_homicides                         7735
# dtype: int64

# %% [markdown]
# ### **Imputing using KNN Imputer for Missing Values**

# %%
imputing_columns = data_copy.drop(['country', 'date'], axis='columns').columns

data_cleaned = pd.DataFrame(columns=list(imputing_columns) + ['Country', 'year'])  # Corrected column assignment

for country_name in set(data_copy['country']):
    data_imputed = KNNImputer(n_neighbors=21).fit_transform(data_copy[data_copy['country'] == country_name][imputing_columns])
    imputed_df = pd.DataFrame(data_imputed, columns=imputing_columns)
    imputed_df['Country'] = country_name
    imputed_df['year'] = pd.to_datetime(data_copy.loc[data_copy['country'] == country_name, 'date']).dt.year.values
    pd.concat([data_cleaned, imputed_df], ignore_index=True)

# %%
data_cleaned.isnull().sum()
# Out:
# agricultural_land%                           0.0
# forest_land%                                 0.0
# land_area                                    0.0
# avg_precipitation                            0.0
# trade_in_services%                           0.0
# control_of_corruption_estimate               0.0
# control_of_corruption_std                    0.0
# access_to_electricity%                       0.0
# renewvable_energy_consumption%               0.0
# electric_power_consumption                   0.0
# CO2_emisions                                 0.0
# other_greenhouse_emisions                    0.0
# population_density                           0.0
# inflation_annual%                            0.0
# real_interest_rate                           0.0
# risk_premium_on_lending                      0.0
# research_and_development_expenditure%        0.0
# central_goverment_debt%                      0.0
# tax_revenue%                                 0.0
# expense%                                     0.0
# goverment_effectiveness_estimate             0.0
# goverment_effectiveness_std                  0.0
# human_capital_index                          0.0
# doing_business                               0.0
# time_to_get_operation_license                0.0
# statistical_performance_indicators           0.0
# individuals_using_internet%                  0.0
# logistic_performance_index                   0.0
# military_expenditure%                        0.0
# GDP_current_US                               0.0
# political_stability_estimate                 0.0
# political_stability_std                      0.0
# rule_of_law_estimate                         0.0
# rule_of_law_std                              0.0
# regulatory_quality_estimate                  0.0
# regulatory_quality_std                       0.0
# government_expenditure_on_education%         0.0
# government_health_expenditure%               0.0
# multidimensional_poverty_headcount_ratio%    0.0
# gini_index                                   0.0
# birth_rate                                   0.0
# death_rate                                   0.0
# life_expectancy_at_birth                     0.0
# population                                   0.0
# rural_population                             0.0
# voice_and_accountability_estimate            0.0
# voice_and_accountability_std                 0.0
# intentional_homicides                        0.0
# Country                                      0.0
# year                                         0.0
# dtype: float64

# %% [markdown]
# ### **Exporting the Cleaned Data**

# %%
data_cleaned.to_csv('country_data_cleaned.csv')
